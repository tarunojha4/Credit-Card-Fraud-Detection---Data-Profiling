# %%
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')
df

# %%
df.shape

# %%
df.head()

# %%
df.sample(5)

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()

# %%
df.duplicated().sum()

# %%
# !pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport
profile =  ProfileReport(df,title = 'credit_card_fraud_detection_data_profiling', minimal = True)
profile.to_file(output_file = "report_html")

# %%
import os
